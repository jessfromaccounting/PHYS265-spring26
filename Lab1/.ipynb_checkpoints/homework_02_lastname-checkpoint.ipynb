# %% [markdown]
# # Homework 2
#
# Your Name Goes Here: **Firstname Lastname**
#
# The date goes here: **February 2, 2026**

# %% [markdown]
# ### Question 1
# ---

# %%
# your answer goes in this code cell

# %% [markdown]
# ### Question 2
# ---

# %%
# your answer goes in this code cell

# %% [markdown]
# ### Question 3
# ---

# %%
# your answer goes in this code cell

# %% [markdown]
# ### Question 4
# ---

# %%
# print table header
